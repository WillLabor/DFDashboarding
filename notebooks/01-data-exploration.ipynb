# %% [markdown]
# # Data Exploration
#
# This notebook is a starting point for loading API-exported CSV data and exploring it.

# %%
import pandas as pd
from pathlib import Path

# Update this path to point at a CSV exported by `src/data_loader.py`
csv_path = Path('data/output.csv')

df = pd.read_csv(csv_path)
df.head()
